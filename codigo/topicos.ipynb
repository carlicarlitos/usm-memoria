# %% [markdown]
# # Analisis de Tópicos

# %%
import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            continue
        elif token.orth_.startswith('@'):
            continue
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\carlo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\carlo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 3]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
import random
import pandas as pd


csv1 = pd.read_csv('twentyfive_thirty.csv', encoding='iso-8859-1')
csv1_grouped_by_thread = csv1.groupby(['thread_number'])

texts1 = {}
#string = " \n "
documentos1 = []
for thread, data in dict(list(csv1_grouped_by_thread)).items():
#    texts1[thread] = string.join(list(data['text']))
    texts1[thread] = list(data['text'])
    

documentos1 = texts1["Thread 1"]    
#documentos1 = list(texts1.values())
#l = list(texts1.values())
#documentos1 = [item for sublist in l for item in sublist]

# %%
texts1
# Out:
# {'Thread 1': ['(1) @DeadofKnight68 asks a question. https://t.co/IBkNFfm0ju',
#   "(2) In North Korea, the Kim family and the Korean People's Army (KPA) are holding each other hostage.\r\r\n\r\r\nThe KPA is t\x85 https://t.co/gj1Ka9T2pI",
#   '(3) The KPA needs a central figure who serves as the face of the nation.\r\r\n\r\r\nSo the Kim family has had to PROVE to the\x85 https://t.co/AR9ISMwuX8',
#   '(4) KPA generals live in palaces.\r\r\n\r\r\nSome of them are bigger than the Mall of the Americas. https://t.co/RCWxFtWy9S',
#   '(5) The Kim family and the KPA are twin mafias.\r\r\n\r\r\nThey extort the world and have done so since 1953.',
#   '(6) So what HAPPENED FIRST is that Donald Trump used North Korean rhetoric in response to threats from North Korea.\x85 https://t.co/SqiQItG2Jm',
#   '(7) Although it was reported that the North Koreans were asking for advice from former American government official\x85 https://t.co/u7C61xuH1M',
# ...

# %%
text_data = []

for line in documentos1:
    print(line)
    tokens = prepare_text_for_lda(line)
    if random.random() > .09:
        print(tokens)
        text_data.append(tokens)
# Out:
# (1) @DeadofKnight68 asks a question. https://t.co/IBkNFfm0ju
#  (2) In North Korea, the Kim family and the Korean People's Army (KPA) are holding each other hostage.
#
# The KPA is t https://t.co/gj1Ka9T2pI
#  (3) The KPA needs a central figure who serves as the face of the nation.
#
# So the Kim family has had to PROVE to the https://t.co/AR9ISMwuX8
#  (4) KPA generals live in palaces.
#
# Some of them are bigger than the Mall of the Americas. https://t.co/RCWxFtWy9S
#  (5) The Kim family and the KPA are twin mafias.
#
# They extort the world and have done so since 1953.
#  (6) So what HAPPENED FIRST is that Donald Trump used North Korean rhetoric in response to threats from North Korea. https://t.co/SqiQItG2Jm
#  (7) Although it was reported that the North Koreans were asking for advice from former American government official https://t.co/u7C61xuH1M
#  (8) In the PAST, we set conditions for talks.
#
# A giant waste of time.
# ...

# %%
text_data
# Out:
# [['ask',
#   'question',
#   'north',
#   'korea',
#   'family',
#   'korean',
#   'people',
#   'army',
#   'holding',
#   'hostage',
#   'need',
#   'central',
#   'figure',
#   'serve',
#   'face',
#   'nation',
#   'family',
#   'prove',
#   'general',
#   'live',
#   'palace',
#   'bigger',
#   'mall',
#   'america',
#   'family',
#   'twin',
#   'mafia',
#   'extort',
#   'world',
#   'do',
#   'since',
#   '1953',
#   'happen',
#   'first',
#   'donald',
#   'trump',
#   'use',
#   'north',
#   'korean',
#   'rhetoric',
#   'response',
#   'threat',
#   'north',
#   'korea',
#   'although',
#   'report',
#   'north',
#   'korean',
#   'asking',
#   'advice',
#   'former',
#   'american',
#   'government',
#   'official',
#   'past',
#   'conditions',
#   'talks',
#   'giant',
#   'waste',
#   'time',
#   'twice',
#   '2017',
#   'jimmy',
#   'carter',
#   'return',
#   'home',
#   'flying',
#   'jolly',
#   'roger',
#   'signify',
#   'successful',
#   'combat',
# ...

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.008*"trump" + 0.005*"people" + 0.004*"white" + 0.004*"comey" + 0.004*"say" + 0.003*"make" + 0.003*"could" + 0.003*"take"')
# (1, '0.019*"qanon" + 0.012*"trump" + 0.006*"post" + 0.006*"page" + 0.006*"bombshell" + 0.005*"path" + 0.005*"russia" + 0.005*"openingday"')
# (2, '0.006*"people" + 0.005*"say" + 0.005*"post" + 0.004*"4/4/18" + 0.004*"qalert" + 0.004*"know" + 0.003*"time" + 0.003*"moore"')
# (3, '0.013*"trump" + 0.005*"qanon" + 0.004*"facebook" + 0.004*"nunes" + 0.004*"mueller" + 0.003*"know" + 0.003*"right" + 0.003*"enough"')
# (4, '0.006*"people" + 0.006*"know" + 0.004*"say" + 0.004*"royalwedding" + 0.004*"simulation" + 0.003*"food" + 0.003*"mueller" + 0.003*"look"')

# %%
new_doc = texts1["Thread 1"]

# %%
new_doc
# Out:
# '(1) @DeadofKnight68 asks a question. https://t.co/IBkNFfm0ju \n (2) In North Korea, the Kim family and the Korean People\'s Army (KPA) are holding each other hostage.\r\r\n\r\r\nThe KPA is t\x85 https://t.co/gj1Ka9T2pI \n (3) The KPA needs a central figure who serves as the face of the nation.\r\r\n\r\r\nSo the Kim family has had to PROVE to the\x85 https://t.co/AR9ISMwuX8 \n (4) KPA generals live in palaces.\r\r\n\r\r\nSome of them are bigger than the Mall of the Americas. https://t.co/RCWxFtWy9S \n (5) The Kim family and the KPA are twin mafias.\r\r\n\r\r\nThey extort the world and have done so since 1953. \n (6) So what HAPPENED FIRST is that Donald Trump used North Korean rhetoric in response to threats from North Korea.\x85 https://t.co/SqiQItG2Jm \n (7) Although it was reported that the North Koreans were asking for advice from former American government official\x85 https://t.co/u7C61xuH1M \n (8) In the PAST, we set conditions for talks.\r\r\n\r\r\nA giant waste of time. \n (
# ...

# %%
new_doc = prepare_text_for_lda(new_doc)
new_doc_bow = dictionary.doc2bow(new_doc)
print(new_doc_bow)
print(ldamodel.get_document_topics(new_doc_bow))
# Out:
# [(0, 1), (1, 1), (2, 1), (3, 2), (4, 1), (5, 1), (6, 2), (7, 1), (8, 1), (9, 1), (10, 1), (11, 2), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 2), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 2), (27, 1), (28, 1), (29, 1), (30, 1), (31, 2), (32, 1), (33, 1), (34, 1), (35, 1), (36, 2), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 2), (51, 1), (52, 1), (53, 1), (54, 1), (55, 3), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 2), (64, 1), (65, 1), (66, 2), (67, 1), (68, 1), (69, 1), (70, 1), (71, 2), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 1), (82, 1), (83, 1), (84, 2), (85, 1), (86, 1), (87, 1), (88, 1), (89, 1), (90, 2), (91, 1), (92, 1), (93, 1), (94, 2), (95, 1), (96, 3), (97, 6), (98, 1), (99, 1), (100, 1), (101, 1), (102, 1), (103, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 1
# ...

# %%
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2151616570847342249400143607"></div>
# <script type="text/javascript">
#
# ...
